# %%
# !pip install -q gdown
import gdown, os

url = "https://drive.google.com/drive/folders/1DzW8ARnZt7g0_MxcXVAw43fKP_oA7hnR?usp=sharing"
out = "/content/shared_folder"
os.makedirs(out, exist_ok=True)

gdown.download_folder(url=url, output=out, quiet=False, use_cookies=False)
print("다운로드 완료!")
# !ls -R {out}
